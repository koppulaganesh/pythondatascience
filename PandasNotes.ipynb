# %% [markdown]
# # Pandas  (PANelDAta)

# %%
#Pandas is used for the data handling. It is very easy to import and export data using pandas library.

# %%
import pandas

# %%
import pandas as pd

# %%
import pandas as pd    #aliasing

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %%
d=pd.read_csv("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\cv.csv")

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %%
import pandas as pd

# %% [markdown]
# # Creating DataFrame using dictionary:

# %%
di={"Name":["Ganesh","Ramu","Jai"],"Roll_No":[1,2,3],"Percentage":[80,70,60]}

# %%
di
# Out:
# {'Name': ['Ganesh', 'Ramu', 'Jai'],
#  'Roll_No': [1, 2, 3],
#  'Percentage': [80, 70, 60]}

# %%
df2=pd.DataFrame(di)

# %%
df2
# Out:
#      Name  Roll_No  Percentage
# 0  Ganesh        1          80
# 1    Ramu        2          70
# 2     Jai        3          60

# %% [markdown]
# # Creating DataFrame using list of tuples

# %%
c=[("Ganesh",1,80),("Ramu",2,70),("Jai",3,60)]

# %%
df3=pd.DataFrame(c)

# %%
df3
# Out:
#         0  1   2
# 0  Ganesh  1  80
# 1    Ramu  2  70
# 2     Jai  3  60

# %% [markdown]
# # Covid Data State-Wise

# %%
a=pd.read_csv("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\covid.csv")

# %%
df=pd.DataFrame(a)

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %% [markdown]
# # Indexing & Slicing

# %% [markdown]
# ### df.head()

# %%
df.head()    #it will return top five data if dont give any inputs
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.head(2)   #it will return first two data
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364

# %% [markdown]
# ### df.tail()

# %%
df.tail()    #it will return last five data
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 31      Telengana       844432       8      840313    4111          0.00
# 32        Tripura       108493       1      107550     942          0.00
# 33  Uttar Pradesh      2145431      57     2121662   23712          0.00
# 34    Uttarakhand       452571       0      444803    7768          0.00
# 35    West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 31            99.51         0.49    69599762
# 32            99.13         0.87     1646050
# 33            98.89         1.11     1158040
# 34            98.28         1.72    85002417
# 35            98.98         1.01    32199722

# %%
df.tail(2)     #it will return last two data only
# Out:
#       State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 34  Uttarakhand       452571       0      444803    7768          0.00
# 35  West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 34            98.28         1.72    85002417
# 35            98.98         1.01    32199722

# %%
df.tail(10) #it will display last 10 records
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 26     Puducherry       177547       0      175566    1981          0.00
# 27         Punjab       793644    1233      773073   19338          0.16
# 28      Rajasthan      1326465       2     1316727    9736          0.00
# 29         Sikkim        44927       4       44422     501          0.01
# 30     Tamil Nadu      3610655       5     3572569   38081          0.00
# 31      Telengana       844432       8      840313    4111          0.00
# 32        Tripura       108493       1      107550     942          0.00
# 33  Uttar Pradesh      2145431      57     2121662   23712          0.00
# 34    Uttarakhand       452571       0      444803    7768          0.00
# 35    West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 26            98.88         1.12     2073074
# 27            97.41         2.44    34698876
# ...

# %% [markdown]
# ### df.describe()

# %%
df.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.249975e+06    50.333333  1.235146e+06   14778.527778      0.005000
# std    1.846038e+06   207.118048  1.820328e+06   27221.140636      0.026673
# min    1.076600e+04     0.000000  1.063700e+04       4.000000      0.000000
# 25%    1.065430e+05     0.000000  1.055395e+05    1124.250000      0.000000
# 50%    6.140910e+05     1.500000  6.076750e+05    6551.000000      0.000000
# 75%    1.331951e+06     9.000000  1.322329e+06   14325.750000      0.000000
# max    8.171048e+06  1233.000000  8.022276e+06  148558.000000      0.160000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.897222     1.097778  3.971861e+07
# std           0.506854     0.494791  5.050913e+07
# min          97.410000     0.030000  6.600100e+04
# ...

# %% [markdown]
# ### df.shape

# %%
df.shape    #it will return no.of rows and columns
# Out:
# (36, 9)

# %% [markdown]
# ### df[start:stop:step]

# %%
df[1:10:2] #1=start,10=stop,2=difference #note:10 will not include while returning
# Out:
#                                   State/UTs  Total Cases  Active  Discharged  \
# 1                            Andhra Pradesh      2340676       0     2325943
# 3                                     Assam       746159       5      738119
# 5                                Chandigarh       100693       0       99508
# 7  Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 9                                       Goa       263346       3      259329
#
#    Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# 1   14733           0.0            99.37         0.63   128500364
# 3    8035           0.0            98.92         1.08      290492
# 5    1185           0.0            98.82         1.18    30501026
# 7       4           0.0            99.97         0.03   231502578
# 9    4014           0.0            98.47         1.52     3772103

# %% [markdown]
# ### df["Column_Name"]

# %%
 df["State/UTs"]     #accessing the complete column using column name
# Out:
# 0                          Andaman and Nicobar
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %% [markdown]
# ### df[["column1","column2"]]       #list of index

# %%
df[["State/UTs","Total Cases"]]
# Out:
#                                    State/UTs  Total Cases
# 0                        Andaman and Nicobar        10766
# 1                             Andhra Pradesh      2340676
# 2                          Arunachal Pradesh        67049
# 3                                      Assam       746159
# 4                                      Bihar       855267
# 5                                 Chandigarh       100693
# 6                               Chhattisgarh      1187695
# 7   Dadra and Nagar Haveli and Daman and Diu        11592
# 8                                      Delhi      2040910
# 9                                        Goa       263346
# 10                                   Gujarat      1291383
# 11                                   Haryana      1078903
# 12                          Himachal Pradesh       322905
# 13                         Jammu and Kashmir       482023
# 14                                 Jharkhand       443826
# ...

# %% [markdown]
# ### df[["column1",'column2']][start:stop:step]

# %%
df[['State/UTs','Total Cases','Deaths']] [0:10:2]
# Out:
#              State/UTs  Total Cases  Deaths
# 0  Andaman and Nicobar        10766     129
# 2    Arunachal Pradesh        67049     296
# 4                Bihar       855267   12314
# 6         Chhattisgarh      1187695   14190
# 8                Delhi      2040910   26666

# %% [markdown]
# ### iterrows()

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, State/UTs          Andaman and Nicobar
# Total Cases                      10766
# Active                               0
# Discharged                       10637
# Deaths                             129
# Active Ratio                       0.0
# Discharge Ratio                   98.8
# Death Ratio                        1.2
# Population                   100896618
# Name: 0, dtype: object)
# (1, State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object)
# (2, State/UTs          Arunachal Pradesh
# Total Cases                    67049
# Active                             0
# Discharged                     66753
# Deaths                           296
# Active Ratio                     0.0
# ...

# %% [markdown]
# # loc (location)

# %% [markdown]
# ### df.loc[row_number]

# %%
df.loc[0]
# Out:
# State/UTs          Andaman and Nicobar
# Total Cases                      10766
# Active                               0
# Discharged                       10637
# Deaths                             129
# Active Ratio                       0.0
# Discharge Ratio                   98.8
# Death Ratio                        1.2
# Population                   100896618
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object

# %%
df.loc[31]
# Out:
# State/UTs          Telengana
# Total Cases           844432
# Active                     8
# Discharged            840313
# Deaths                  4111
# Active Ratio             0.0
# Discharge Ratio        99.51
# Death Ratio             0.49
# Population          69599762
# Name: 31, dtype: object

# %% [markdown]
# ### df.loc[rownumber,["column_name1","column_name2"]]

# %%
df.loc[31,["State/UTs","Total Cases","Deaths","Population"]]
# Out:
# State/UTs      Telengana
# Total Cases       844432
# Deaths              4111
# Population      69599762
# Name: 31, dtype: object

# %%
import pandas as pd

# %% [markdown]
# ### df.loc[start:stop]

# %%
df.loc[0:5]    #Note: stop index will be  included here
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
# 5           Chandigarh       100693       0       99508    1185           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376
# 5            98.82         1.18    30501026

# %% [markdown]
# ### df.iloc[start:stop]

# %%
df.iloc[0:5]  #note: stop index will be not included here
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %% [markdown]
# ### df.loc[start:stop,"Column_name"]

# %%
df.loc[0:5,"State/UTs"]     #single column
# Out:
# 0    Andaman and Nicobar
# 1         Andhra Pradesh
# 2      Arunachal Pradesh
# 3                  Assam
# 4                  Bihar
# 5             Chandigarh
# Name: State/UTs, dtype: object

# %% [markdown]
# ### df.loc[start:stop,["Column_name1","Column_name2"]]

# %%
df.loc[0:5,["State/UTs","Population"]]   #multiple column
# Out:
#              State/UTs  Population
# 0  Andaman and Nicobar   100896618
# 1       Andhra Pradesh   128500364
# 2    Arunachal Pradesh      658019
# 3                Assam      290492
# 4                Bihar    40100376
# 5           Chandigarh    30501026

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %% [markdown]
# # df.loc[start:stop,"column1":"column2"]

# %%
df.loc[0:4,"State/UTs":"Deaths"]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths
# 0  Andaman and Nicobar        10766       0       10637     129
# 1       Andhra Pradesh      2340676       0     2325943   14733
# 2    Arunachal Pradesh        67049       0       66753     296
# 3                Assam       746159       5      738119    8035
# 4                Bihar       855267       1      842952   12314

# %% [markdown]
# # iloc(integer location)

# %%
import pandas as np

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.iloc[1]
# Out:
# State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object

# %% [markdown]
# ### df.iloc[row_number,column_number]

# %%
df.iloc[1,1]   #total cases in Andhra Pradesh 1=row number(index), 1=column number(index)
# Out:
# 2340676

# %%
df.loc[1]
# Out:
# State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %% [markdown]
# ### df.iloc[row_start:row_stop,col_start:col_stop]

# %%
df.iloc[0:5,0:5]   #stop is excluded
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths
# 0  Andaman and Nicobar        10766       0       10637     129
# 1       Andhra Pradesh      2340676       0     2325943   14733
# 2    Arunachal Pradesh        67049       0       66753     296
# 3                Assam       746159       5      738119    8035
# 4                Bihar       855267       1      842952   12314

# %% [markdown]
# ### df.iloc[start:stop,column_number]

# %%
df.iloc[1:5,0] #0=column number]
# Out:
# 1       Andhra Pradesh
# 2    Arunachal Pradesh
# 3                Assam
# 4                Bihar
# Name: State/UTs, dtype: object

# %% [markdown]
# ### df.iloc[[row1,row2,...]]

# %%
df.iloc[[0,1,2]]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019

# %% [markdown]
# ### df.iloc[ : ,[col_1,col_2,col_3]]

# %%
df.iloc[:,[0,1,2]]
# Out:
#                                    State/UTs  Total Cases  Active
# 0                        Andaman and Nicobar        10766       0
# 1                             Andhra Pradesh      2340676       0
# 2                          Arunachal Pradesh        67049       0
# 3                                      Assam       746159       5
# 4                                      Bihar       855267       1
# 5                                 Chandigarh       100693       0
# 6                               Chhattisgarh      1187695       0
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0
# 8                                      Delhi      2040910      14
# 9                                        Goa       263346       3
# 10                                   Gujarat      1291383       5
# 11                                   Haryana      1078903      27
# 12                          Himachal Pradesh       322905       4
# ...

# %% [markdown]
# ### df.iloc[start:stop,[col_1,col_2,...]]

# %%
df.iloc[0:5,[0,1,2,3,4]]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths
# 0  Andaman and Nicobar        10766       0       10637     129
# 1       Andhra Pradesh      2340676       0     2325943   14733
# 2    Arunachal Pradesh        67049       0       66753     296
# 3                Assam       746159       5      738119    8035
# 4                Bihar       855267       1      842952   12314

# %% [markdown]
# # Sorting DataFrame

# %% [markdown]
# ### df.sort_values("column_name")

# %%
df.sort_values("Deaths")    #bydefault it is ascending=True #Ascending order arranges values from the smallest to the largest.
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 18                               Lakshadweep        11415       0       11363
# 0                        Andaman and Nicobar        10766       0       10637
# 17                                    Ladakh        29602       0       29371
# 2                          Arunachal Pradesh        67049       0       66753
# 29                                    Sikkim        44927       4       44422
# 23                                   Mizoram       239560       1      238825
# 24                                  Nagaland        36033       0       35251
# 32                                   Tripura       108493       1      107550
# 5                                 Chandigarh       100693       0       99508
# 22                                 Meghalaya        96983       3       95352
# ...

# %%
df.sort_values("Deaths",ascending=False) #Ascending order arranges values from the smallest to the largest.
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 20                               Maharashtra      8171048     214     8022276
# 16                                    Kerala      6907241      18     6835181
# 15                                 Karnataka      4088769      12     4048399
# 30                                Tamil Nadu      3610655       5     3572569
# 8                                      Delhi      2040910      14     2014230
# 33                             Uttar Pradesh      2145431      57     2121662
# 35                               West Bengal      2126282     135     2104592
# 27                                    Punjab       793644    1233      773073
# 1                             Andhra Pradesh      2340676       0     2325943
# 6                               Chhattisgarh      1187695       0     1173505
# 4                                      Bihar       855267       1      842952
# ...

# %% [markdown]
# ### df.sort_values(["col_1","col_2"])

# %%
df.sort_values(["State/UTs","Deaths"])   #"col_1"=ascending order
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.sort_values(["State/UTs","Deaths"],ascending=[0,1]) #0=False,1=True
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 35                               West Bengal      2126282     135     2104592
# 34                               Uttarakhand       452571       0      444803
# 33                             Uttar Pradesh      2145431      57     2121662
# 32                                   Tripura       108493       1      107550
# 31                                 Telengana       844432       8      840313
# 30                                Tamil Nadu      3610655       5     3572569
# 29                                    Sikkim        44927       4       44422
# 28                                 Rajasthan      1326465       2     1316727
# 27                                    Punjab       793644    1233      773073
# 26                                Puducherry       177547       0      175566
# 25                                    Odisha      1348409      59     1339135
# ...

# %%
import pandas as pd

# %%
df.sort_values(["State/UTs","Deaths"],ascending=[0,1]) #0=False,1=True
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 35                               West Bengal      2126282     135     2104592
# 34                               Uttarakhand       452571       0      444803
# 33                             Uttar Pradesh      2145431      57     2121662
# 32                                   Tripura       108493       1      107550
# 31                                 Telengana       844432       8      840313
# 30                                Tamil Nadu      3610655       5     3572569
# 29                                    Sikkim        44927       4       44422
# 28                                 Rajasthan      1326465       2     1316727
# 27                                    Punjab       793644    1233      773073
# 26                                Puducherry       177547       0      175566
# 25                                    Odisha      1348409      59     1339135
# ...

# %%
df.sort_values(["State/UTs","Deaths"],ascending=[1,0]) #0=False,1=True
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %% [markdown]
# # Manipulating DataFrame

# %% [markdown]
# ### Adding Column:

# %% [markdown]
# ### df["new_col_name"]=default_value

# %%
df["Total"]=0 #a new column named as "Total"

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df["Total"]=df["Total Cases"]-df["Discharged"]

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
c={"Name":["Ganesh","Ramu","Jai"],"Roll_No":[1,2,3],"Telugu":[45,60,70],"Hindi":[80,90,50]}

# %%
df1=pd.DataFrame(c)

# %%
df1
# Out:
#      Name  Roll_No  Telugu  Hindi
# 0  Ganesh        1      45     80
# 1    Ramu        2      60     90
# 2     Jai        3      70     50

# %%
df1["Total"]=0

# %%
df1
# Out:
#      Name  Roll_No  Telugu  Hindi  Total
# 0  Ganesh        1      45     80      0
# 1    Ramu        2      60     90      0
# 2     Jai        3      70     50      0

# %%
df1["Total"]=df1["Telugu"]+df1["Hindi"]

# %%
df1
# Out:
#      Name  Roll_No  Telugu  Hindi  Total
# 0  Ganesh        1      45     80    125
# 1    Ramu        2      60     90    150
# 2     Jai        3      70     50    120

# %% [markdown]
# ### Removing Column

# %% [markdown]
# ### df.drop(columns="column_name")    #for temporary removal of certain column

# %%
df1["Percentage"]=0   #adding the column

# %%
df1
# Out:
#      Name  Roll_No  Telugu  Hindi  Total  Percentage
# 0  Ganesh        1      45     80    125           0
# 1    Ramu        2      60     90    150           0
# 2     Jai        3      70     50    120           0

# %%
df1.drop(columns="Percentage") #Temporary removal of a column
# Out:
#      Name  Roll_No  Telugu  Hindi  Total
# 0  Ganesh        1      45     80    125
# 1    Ramu        2      60     90    150
# 2     Jai        3      70     50    120

# %% [markdown]
# ### df.drop(columns="column_name",inplace=True)  #for permanent removal of the column

# %%
df1.drop(columns="Percentage",inplace=True)  #for permanent removal of a column

# %%
df1
# Out:
#      Name  Roll_No  Telugu  Hindi  Total
# 0  Ganesh        1      45     80    125
# 1    Ramu        2      60     90    150
# 2     Jai        3      70     50    120

# %% [markdown]
# # Removing Duplicates

# %% [markdown]
# ### Knowing whether we have duplicates or not

# %% [markdown]
# ### df.duplicated()

# %%
#Note: We get the results in the Boolean format

# %%
a={"Name":["Ganesh","Rajesh","Suresh","Kamesh","Suresh"],"S/O":["Mahesh","Naresh","Gopi","Ramakanth","Gopi"]}

# %%
df2=np.DataFrame(a)

# %%
df2
# Out:
#      Name        S/O
# 0  Ganesh     Mahesh
# 1  Rajesh     Naresh
# 2  Suresh       Gopi
# 3  Kamesh  Ramakanth
# 4  Suresh       Gopi

# %%
df2.duplicated() #True represents that we got one duplicate
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ### df.drop_duplicates()

# %%
df2.drop_duplicates()
# Out:
#      Name        S/O
# 0  Ganesh     Mahesh
# 1  Rajesh     Naresh
# 2  Suresh       Gopi
# 3  Kamesh  Ramakanth

# %% [markdown]
# ### df.drop_duplicates(inplace=True)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2
# Out:
#      Name        S/O
# 0  Ganesh     Mahesh
# 1  Rajesh     Naresh
# 2  Suresh       Gopi
# 3  Kamesh  Ramakanth

# %% [markdown]
# # Handling Missing Data

# %% [markdown]
# ### Fill with the default values

# %% [markdown]
# ### df.fillna(default_values)

# %%
e=pd.read_csv("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\cv.csv")

# %%
df5=np.DataFrame(e)

# %%
df5
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %%
df5.fillna("NTA")
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %% [markdown]
# ### Remove Missing Data

# %%
df5
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %% [markdown]
# ### df.dropna()

# %%
df5.dropna()  #the missing data row will be deleted for temporary purpose
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 5                 4                       30             8        Obese
# 6                 6                       40             7        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea
# 5         140/90          85         3000       Insomnia
# 6         140/90          82         3500       Insomnia

# %% [markdown]
# ### df.dropna(inplace=True)

# %%
df5.dropna(inplace=True)   #To the row of the missing data deleted permanently

# %%
df5
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 5                 4                       30             8        Obese
# 6                 6                       40             7        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea
# 5         140/90          85         3000       Insomnia
# 6         140/90          82         3500       Insomnia

# %%
df5 #the row of the missing data permanently
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 5                 4                       30             8        Obese
# 6                 6                       40             7        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea
# 5         140/90          85         3000       Insomnia
# 6         140/90          82         3500       Insomnia

# %% [markdown]
# # Data Filtering and Conditional Changes

# %% [markdown]
# ### df.loc[simple_condition]

# %%
a=pd.read_csv("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\covid.csv")

# %%
df=np.DataFrame(a)

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.loc[df["Deaths"]>10000]  #the states/Uts in which deaths are greater than ten thousand
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1   Andhra Pradesh      2340676       0     2325943   14733          0.00
# 4            Bihar       855267       1      842952   12314          0.00
# 6     Chhattisgarh      1187695       0     1173505   14190          0.00
# 8            Delhi      2040910      14     2014230   26666          0.00
# 10         Gujarat      1291383       5     1280299   11079          0.00
# 11         Haryana      1078903      27     1068121   10755          0.00
# 15       Karnataka      4088769      12     4048399   40358          0.00
# 16          Kerala      6907241      18     6835181   72042          0.00
# 19  Madhya Pradesh      1056351       0     1045565   10786          0.00
# 20     Maharashtra      8171048     214     8022276  148558          0.00
# 27          Punjab       793644    1233      773073   19338          0.16
# 30      Tamil Nadu      3610655       5     3572569   38081          0.00
# ...

# %% [markdown]
# ### df.loc[compound_condition]

# %%
c={"Name":["Ganesh","Ramu","Jai"],"Roll_No":[1,2,3],"Telugu":[45,60,70],"Hindi":[10,90,50],"English":[35,50,50],"Maths":[50,90,50],"Science":[35,70,50],"Social":[20,50,60]}

# %%
df=np.DataFrame(c)

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social
# 0  Ganesh        1      45     10       35     50       35      20
# 1    Ramu        2      60     90       50     90       70      50
# 2     Jai        3      70     50       50     50       50      60

# %%
df.loc[(df["Telugu"]>50) & (df["Hindi"]<80)] #compound condition
# Out:
#   Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social
# 2  Jai        3      70     50       50     50       50      60

# %% [markdown]
# ### df.loc[simple_condition.str.contains(str)]

# %%
df.loc[df["Name"].str.contains("a")]   #it will return the names which contains letter "a"
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social
# 0  Ganesh        1      45     10       35     50       35      20
# 1    Ramu        2      60     90       50     90       70      50
# 2     Jai        3      70     50       50     50       50      60

# %%
df.loc[df["Name"].str.contains("e")]
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social
# 0  Ganesh        1      45     10       35     50       35      20

# %% [markdown]
# ### df.loc[df["Name"].str.startswith("G")]

# %%
df.loc[df["Name"].str.startswith("G")]
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social
# 0  Ganesh        1      45     10       35     50       35      20

# %% [markdown]
# ### df.loc[df["Name"].str.endswith("i")]

# %%
df.loc[df["Name"].str.endswith("i")]
# Out:
#   Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social
# 2  Jai        3      70     50       50     50       50      60

# %%
df["Total"]=0    #adding the column

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total
# 0  Ganesh        1      45     10       35     50       35      20      0
# 1    Ramu        2      60     90       50     90       70      50      0
# 2     Jai        3      70     50       50     50       50      60      0

# %%
df["Total"]=df["Telugu"]+df["Hindi"]

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120

# %%
df["Percentage"]=(df["Total"]/200)*100    #calculating the percentage

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total  \
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120
#
#    Percentage
# 0        27.5
# 1        75.0
# 2        60.0

# %%
df["Grade"]='Pass/Fail'

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total  \
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120
#
#    Percentage      Grade
# 0        27.5  Pass/Fail
# 1        75.0  Pass/Fail
# 2        60.0  Pass/Fail

# %%
df.loc[df["Percentage"]>=50,["Grade"]]="Pass"

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total  \
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120
#
#    Percentage      Grade
# 0        27.5  Pass/Fail
# 1        75.0       Pass
# 2        60.0       Pass

# %%
df.loc[df["Percentage"]<=35,["Grade"]]="Fail"

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total  \
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120
#
#    Percentage Grade
# 0        27.5  Fail
# 1        75.0  Pass
# 2        60.0  Pass

# %%
df.loc[(df["Percentage"]>=35) & (df["Percentage"]<=60),["Grade"]]='Pass'

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total  \
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120
#
#    Percentage Grade
# 0        27.5  Fail
# 1        75.0  Pass
# 2        60.0  Pass

# %%
df.loc[(df["Percentage"]>=50),["Grade"]]="First Class"

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total  \
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120
#
#    Percentage        Grade
# 0        27.5         Fail
# 1        75.0  First Class
# 2        60.0  First Class

# %%
df.loc[(df["Percentage"]>=70),["Grade"]]="Distinction"

# %%
df
# Out:
#      Name  Roll_No  Telugu  Hindi  English  Maths  Science  Social  Total  \
# 0  Ganesh        1      45     10       35     50       35      20     55
# 1    Ramu        2      60     90       50     90       70      50    150
# 2     Jai        3      70     50       50     50       50      60    120
#
#    Percentage        Grade
# 0        27.5         Fail
# 1        75.0  Distinction
# 2        60.0  First Class

# %% [markdown]
# # Export DataFrame to Excel,csv & Text file

# %% [markdown]
# ### df.to_excel("Path")

# %%
df.to_excel("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\Marks_with_grades_excel.xlsx")

# %% [markdown]
# ### df.to_excel("path",index=False)

# %%
df.to_excel("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\Marks_with_grades_excel.xlsx",index=False)

# %% [markdown]
# ### df.to_csv("path")

# %%
df.to_csv("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\Marks_with_grades_csv.csv")

# %% [markdown]
# ### df.to_csv("path",index=False)

# %%
df.to_csv("C:\\Users\\ganig\\OneDrive\\Desktop\\Dataset\\Marks_with_grades_csv.csv",index=False)

# %%
df.Telugu.plot()
# Out:
# <Axes: >
